# %% [markdown]
# Panda

# %%
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter'],
    'Age': [28, 24, 35],
    'City': ['New York', 'Paris', 'Berlin']
}

print(data)
print(data['Name'])
# Out:
# {'Name': ['John', 'Anna', 'Peter'], 'Age': [28, 24, 35], 'City': ['New York', 'Paris', 'Berlin']}
# ['John', 'Anna', 'Peter']

# %%
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   24     Paris
# 2  Peter   35    Berlin
# <class 'pandas.core.frame.DataFrame'>

# %%
df2 =  pd.read_csv("./Used_Bikes.csv")
print(df2)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df2.head(20)
# Out:
#                                    bike_name     price       city  kms_driven  \
# 0         TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1                Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                       Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                       TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                           Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6              Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7        Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
# 10                  Yamaha YZF-R15 2.0 150cc   72000.0  Bangalore     20000.0
# ...

# %%
df2.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df2.shape
# Out:
# (32648, 8)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df2['bike_name']
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: object

# %%
df2[['bike_name', 'price', 'city']]
# Out:
#                                   bike_name     price       city
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad
# 1               Royal Enfield Classic 350cc  119900.0      Delhi
# 2                      Triumph Daytona 675R  600000.0      Delhi
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore
# ...                                     ...       ...        ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal
# 32645              Bajaj Avenger Street 220   60000.0      Delhi
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune
#
# [32648 rows x 3 columns]

# %%
print(type(df2["price"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df2[['price']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df2['price'][0:6]
# Out:
# 0     35000.0
# 1    119900.0
# 2    600000.0
# 3     65000.0
# 4     80000.0
# 5     53499.0
# Name: price, dtype: float64

# %%
df2[['price']].loc[0:10]
# Out:
#        price
# 0    35000.0
# 1   119900.0
# 2   600000.0
# 3    65000.0
# 4    80000.0
# 5    53499.0
# 6    85000.0
# 7    45000.0
# 8   145000.0
# 9    88000.0
# 10   72000.0

# %%
df2.loc[0:10,['price', 'city']]       #loc[row, column] for slicing     # use label
# Out:
#        price       city
# 0    35000.0  Ahmedabad
# 1   119900.0      Delhi
# 2   600000.0      Delhi
# 3    65000.0  Bangalore
# 4    80000.0  Bangalore
# 5    53499.0      Delhi
# 6    85000.0      Delhi
# 7    45000.0      Delhi
# 8   145000.0  Bangalore
# 9    88000.0      Delhi
# 10   72000.0  Bangalore

# %%
df2.iloc[0:10, 0:4]  #iloc[row, column] for slicing
# Out:
#                                   bike_name     price       city  kms_driven
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0

# %%
df2.iloc[32643:32648, 1:3]
# Out:
#          price    city
# 32643  39000.0   Delhi
# 32644  30000.0  Karnal
# 32645  60000.0   Delhi
# 32646  15600.0  Jaipur
# 32647  22000.0    Pune

# %%
df2.iloc[-5:, 1:3]
# Out:
#          price    city
# 32643  39000.0   Delhi
# 32644  30000.0  Karnal
# 32645  60000.0   Delhi
# 32646  15600.0  Jaipur
# 32647  22000.0    Pune

# %%
df2.tail(-5)
# Out:
#                                       bike_name     price       city  \
# 5                              Yamaha FZs 150cc   53499.0      Delhi
# 6                 Honda CB Hornet 160R  ABS DLX   85000.0      Delhi
# 7           Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi
# 8             Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi
# ...                                         ...       ...        ...
# 32643                    Hero Passion Pro 100cc   39000.0      Delhi
# 32644                      TVS Apache RTR 180cc   30000.0     Karnal
# 32645                  Bajaj Avenger Street 220   60000.0      Delhi
# 32646                 Hero Super Splendor 125cc   15600.0     Jaipur
# 32647                        Bajaj Pulsar 150cc   22000.0       Pune
#
#        kms_driven         owner   age  power          brand
# 5         25000.0   First Owner   6.0  150.0         Yamaha
# ...

# %%
df2[['price']].min()
# Out:
# price    4400.0
# dtype: float64

# %%
df2[['price']]
# Out:
#           price
# 0       35000.0
# 1      119900.0
# 2      600000.0
# 3       65000.0
# 4       80000.0
# ...         ...
# 32643   39000.0
# 32644   30000.0
# 32645   60000.0
# 32646   15600.0
# 32647   22000.0
#
# [32648 rows x 1 columns]

# %%
df2[['price']].max()
# Out:
# price    1900000.0
# dtype: float64

# %%
df2['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
first_hand =  df2[df2['owner'] == 'First Owner']
print(first_hand)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df2[df2['price'] > 50000]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# ...                                     ...       ...        ...         ...
# 32634       Royal Enfield Thunderbird 350cc   70000.0     Mumbai     13858.0
# 32636                          KTM RC 390cc  196700.0     Mumbai     13216.0
# 32638                 Yamaha Fazer 25 250cc  123000.0     Kadapa     14500.0
# 32639           Royal Enfield Classic 350cc   95500.0      Delhi     18000.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
#
# ...

# %%
first_hand.to_csv('first_hand.csv', index=False)

# %%
filter_Data = df2[(df2['owner'] == 'First Owner') & (df2['price'] <= 40000)& (df2['age'] <= 3)]
print(filter_Data)
filter_Data.to_csv('filter_Data.csv', index=False)
# Out:
#                                 bike_name    price        city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0   Ahmedabad     17654.0
# 47             Mahindra Centuro NXT 110cc  28000.0      Jaipur     45000.0
# 78                     Bajaj CT 100 100cc  30000.0       Noida      8250.0
# 320   Hero Splendor Plus Kick Alloy 100cc  40000.0       Delhi      9000.0
# 619              Bajaj V15 150cc POWER UP  35000.0      Mumbai     26000.0
# ...                                   ...      ...         ...         ...
# 7371                   Bajaj CT 100 100cc  27000.0   Faridabad     22115.0
# 7374             Hero HF Deluxe Eco 100cc  35000.0   Faridabad     18303.0
# 7672                      TVS Sport 100cc  32000.0     Gurgaon     23000.0
# 7835                Bajaj CT 100 KS Alloy  40000.0  Chandigarh      1501.0
# 8133  Bajaj Platina 100cc ComforTec Alloy  39600.0   Ahmedabad      9000.0
#
#             owner  age  power     brand
# ...

# %%
df2[(df2['owner'] == 'First Owner') | (df2['price'] <= 40000)& (df2['age'] <= 3)]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
 df2[(df2['brand'] == "KTM") & (df2['price'] <= 80000)]
# Out:
#            bike_name    price           city  kms_driven         owner  age  \
# 35    KTM Duke 200cc  70000.0         Nashik    100000.0  Second Owner  8.0
# 129   KTM Duke 200cc  68000.0          Delhi     16000.0   First Owner  9.0
# 602   KTM Duke 200cc  72250.0           Pune      6282.0   First Owner  5.0
# 1016  KTM Duke 200cc  61000.0          Delhi     16000.0   Third Owner  9.0
# 1428  KTM Duke 200cc  62240.0           Pune      3706.0   First Owner  7.0
# 1434  KTM Duke 200cc  64999.0         Mumbai     30000.0   First Owner  9.0
# 1517  KTM Duke 200cc  68000.0         Mumbai     20000.0  Second Owner  9.0
# 1527  KTM Duke 200cc  68000.0         Mumbai     20000.0  Second Owner  9.0
# 1706  KTM Duke 200cc  75000.0          Delhi     35000.0   First Owner  7.0
# 1765  KTM Duke 200cc  71000.0         Rajkot     46000.0   First Owner  8.0
# 2113  KTM Duke 200cc  71000.0         Rajkot     46000.0   First Owner  8.0
# ...

# %%
bike =  df2[(df2['brand'] == "KTM") & (df2['price'] <= 80000)]
print(bike)
row = len(bike)
print(row)
# Out:
#            bike_name    price           city  kms_driven         owner  age  \
# 35    KTM Duke 200cc  70000.0         Nashik    100000.0  Second Owner  8.0
# 129   KTM Duke 200cc  68000.0          Delhi     16000.0   First Owner  9.0
# 602   KTM Duke 200cc  72250.0           Pune      6282.0   First Owner  5.0
# 1016  KTM Duke 200cc  61000.0          Delhi     16000.0   Third Owner  9.0
# 1428  KTM Duke 200cc  62240.0           Pune      3706.0   First Owner  7.0
# 1434  KTM Duke 200cc  64999.0         Mumbai     30000.0   First Owner  9.0
# 1517  KTM Duke 200cc  68000.0         Mumbai     20000.0  Second Owner  9.0
# 1527  KTM Duke 200cc  68000.0         Mumbai     20000.0  Second Owner  9.0
# 1706  KTM Duke 200cc  75000.0          Delhi     35000.0   First Owner  7.0
# 1765  KTM Duke 200cc  71000.0         Rajkot     46000.0   First Owner  8.0
# 2113  KTM Duke 200cc  71000.0         Rajkot     46000.0   First Owner  8.0
# ...

# %%
df2['city'].value_counts()
# Out:
# city
# Delhi            7318
# Bangalore        2723
# Mumbai           2591
# Hyderabad        2160
# Pune             1724
#                  ...
# Surendranagar       1
# Khandela            1
# Mohammadabad        1
# Shimla              1
# Sidhi               1
# Name: count, Length: 443, dtype: int64

# %%
df2['city'].unique()
# Out:
# array(['Ahmedabad', 'Delhi', 'Bangalore', 'Mumbai', 'Kalyan', 'Faridabad',
#        'Mettur', 'Hyderabad', 'Kaithal', 'Gurgaon', 'Pune', 'Noida',
#        'Nashik', 'Kochi', 'Allahabad', 'Samastipur', 'Nadiad', 'Lucknow',
#        'Jaipur', 'Karnal', 'Gorakhpur', 'Vidisha', 'Hosur', 'Bagalkot',
#        'Baripara', 'Agra', 'Dharwad', 'Vadodara', 'Jalandhar', 'Surat',
#        'Chennai', 'Navi Mumbai', 'Gandhidham', 'Visakhapatnam',
#        'Thrissur', 'Kolkata', 'Ernakulam', 'Barasat', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Bhopal', 'Hamirpur(hp)', 'Kottayam',
#        'Arrah', 'Patiala', 'Ranga Reddy', 'Mandi', 'Ludhiana', 'Mandya',
#        'Siliguri', 'Aurangabad', 'Kanpur', 'Bhilwara', 'Meerut', 'Rewari',
#        'Ahmednagar', 'Wardha', 'Chandigarh', 'Ranchi', 'Panvel', 'Thane',
#        'Jabalpur', 'Kota', 'Rohtak', 'Rajkot', 'Varanasi', '24 Pargana',
#        'Banka', 'Nagpur', 'Banki', 'Pali', 'Chhatarpur', 'Katihar',
# ...

# %%
jaipur = df2[df2["city"] == "Jaipur"]

# %%
jaipur['brand'].unique()
# Out:
# array(['Mahindra', 'Suzuki', 'Royal Enfield', 'Harley-Davidson', 'Honda',
#        'Hero', 'Bajaj', 'KTM', 'Yamaha', 'TVS', 'Benelli', 'Kawasaki',
#        'Hyosung'], dtype=object)

# %%
jaipur['brand'].value_counts()
# Out:
# brand
# Hero               731
# Bajaj               83
# Honda               53
# TVS                 42
# Yamaha              37
# Royal Enfield       29
# Harley-Davidson      8
# KTM                  8
# Mahindra             6
# Suzuki               5
# Benelli              3
# Kawasaki             1
# Hyosung              1
# Name: count, dtype: int64

# %%
jaipur['brand'].value_counts().sum()
# Out:
# 1007
