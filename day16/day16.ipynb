# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head(100)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# ..         ...   ...     ...    ...  ...     ...   ...
# 95       40.17  4.73    Male    Yes  Fri  Dinner     4
# 96       27.28  4.00    Male    Yes  Fri  Dinner     2
# 97       12.03  1.50    Male    Yes  Fri  Dinner     2
# 98       21.01  3.00    Male    Yes  Fri  Dinner     2
# 99       12.46  1.50    Male     No  Fri  Dinner     2
#
# [100 rows x 7 columns]

# %%
a = sns.boxenplot(df)
a = sns.boxplot(df)

# %%
sns.relplot(x=df['total_bill'], y=df['tip'] , data = df, hue='smoker', style="sex")

# %%
sns.catplot(x=df['smoker'], y=df['total_bill'], data = df, kind = 'bar', )

# %%
sns.catplot(x=df['smoker'], y=df['total_bill'], data = df, kind= "violin" )

# %%
sns.catplot(x=df['smoker'], y=df['total_bill'], data = df, kind= "strip" )

# %%
sns.catplot(x=df['smoker'], y=df['total_bill'], data = df, kind= "point" )

# %%
sns.catplot(x=df['smoker'], y=df['total_bill'], data = df, kind= "box" )

# %%
sns.catplot(x=df['sex'], y=df['total_bill'], data = df, kind= "bar", hue="tip" )

# %%
sns.catplot(x=df['sex'], y=df['total_bill'], data = df, kind= "swarm", hue = "smoker" )

# %%
sns.catplot(x='total_bill', y='tip', data = df, kind= "bar")

# %%
sns.barplot(x='total_bill', y='tip', data = df, hue ="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='total_bill', y='tip', data = df, hue ="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(x='total_bill', y='tip', data = df, hue ="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='total_bill', y='tip', data = df, hue ="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.swarmplot(x='total_bill', y='tip', data = df, hue ="sex")
# Out:
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='total_bill', y='tip', data = df, hue ="sex", kind="bar")

# %%
sns.catplot(x='total_bill', y='tip', data = df, hue ="sex", )

# %%
sns.barplot(x='day', y='tip', data = df, hue ="sex", )
plt.title("JECRC")
plt.ylabel("Total Bill")
plt.xlabel("Day")
plt.show()

# %%
df[df['day'] == "Sat"]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
label = [(df[df['day']=='Sat'].value_counts().keys)]

plt.pie(val, labels=label, wedgeprops=('ec' == 'k'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 3
#       1 label = [(df[df['day']=='Sat'].value_counts().keys)]
# ----> 3 plt.pie(val, labels=label, wedgeprops=('ec' == 'k'))
#       4 plt.show()
#
# File c:\Python312\Lib\site-packages\matplotlib\pyplot.py:3558, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3535 @_copy_docstring_and_deprecators(Axes.pie)
#    3536 def pie(
#    3537     x: ArrayLike,
#    (...)
#    3556     data=None,
#    3557 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3558     return gca().pie(
#    3559         x,
#    3560         explode=explode,
#    3561         labels=labels,
#    3562         colors=colors,
#    3563         autopct=autopct,
# ...

# %%
# val = df[df['day']=='Sat'].value_counts()
# # label = val.index.tolist()

# plt.pie(val, labels=label, wedgeprops={'edgecolor' : 'k'})
# plt.show()

# %%
label = [df['day'].value_counts().keys]
plt.pie(val,  labels=label, wedgeprops={'ec' : 'k'})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 3
#       1 label = [df['day'].value_counts().keys]
# ----> 3 plt.pie(val,  labels=label, wedgeprops={'ec' : 'k'})
#       4 plt.show()
#
# File c:\Python312\Lib\site-packages\matplotlib\pyplot.py:3558, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3535 @_copy_docstring_and_deprecators(Axes.pie)
#    3536 def pie(
#    3537     x: ArrayLike,
#    (...)
#    3556     data=None,
#    3557 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3558     return gca().pie(
#    3559         x,
#    3560         explode=explode,
#    3561         labels=labels,
#    3562         colors=colors,
#    3563         autopct=autopct,
# ...

# %%
ls = [1,0,0,0.2,0.5,2]

plt.pie(ls, wedgeprops={'ec' : 'k'}, explode=ls)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b78df01dc0>,
# ...
#  [Text(1.3874169789547088, 1.5764117883688227, ''),
#   Text(-0.13971951889297426, 1.0910904893913775, ''),
#   Text(-0.13971951889297426, 1.0910904893913775, ''),
#   Text(-0.3806695134089215, 1.2430167824937102, ''),
#   Text(-1.2448571197949736, 1.005152103562323, ''),
#   Text(-0.3937557994925759, -3.0748912778122683, '')])

# %%
label =

# %%
ls = [1,0,0,0.2,0.5,2]

plt.pie(ls, wedgeprops={'ec' : 'k'})    
plt.title("JECRC")
# Out:
# Text(0.5, 1.0, 'JECRC')

# %%
counts = df['day'].value_counts()
labels = counts.index.tolist()

plt.pie(counts, labels=labels, shadow = 2, wedgeprops={'edgecolor' : 'k'})
plt.title("Days")

plt.savefig("pie")
plt.show()

# %%
sns.catplot(x="time", y="total_bill", data=df, kind="bar", hue="day")

# %%
sns.catplot(x="smoker", y="total_bill", data=df, kind="bar", hue="day")

# %%
sns.catplot(x="smoker", y="total_bill", data=df, kind="bar", hue="day", col="sex")

# %%
sns.catplot(x="smoker", y="total_bill", data=df, kind="bar", hue="day", row="sex")

# %%
sns.catplot(x="size", y="total_bill", data=df, kind="bar", hue="day")

# %%
sns.relplot(x="total_bill", y="size", data=df,kind = "line", hue="day")

# %%
# sns.boxplot(df["total_bill"])
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>
